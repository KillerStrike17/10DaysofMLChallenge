# %% [markdown]
# # Day2

# %% [markdown]
# ## Importing heavenly Bodies

# %%
#time to call the gods
import pandas as pd
from sklearn import preprocessing
import numpy as np
# %matplotlib notebook
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import seaborn as sns

# %% [markdown]
# ## Data Loading

# %%
def preprocess_df(df):
    processed_df = df.copy()
    le = preprocessing.LabelEncoder()
    processed_df.Sex = le.fit_transform(processed_df.Sex)
    processed_df.Embarked = le.fit_transform(processed_df.Embarked)
    processed_df.Name = le.fit_transform(processed_df.Name)
    processed_df.Ticket = le.fit_transform(processed_df.Ticket)
    return processed_df

# %%
dataset=pd.read_csv("http://iali.in/datasets/titanic/train.csv")

# %%
dataset.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# ## Data Visualization

# %%
f,ax=plt.subplots(2,2,figsize=(10,6))
sns.countplot(dataset['Survived'],ax=ax[0,0])
dataset['Survived'].value_counts().plot.pie(explode=[0,0.1],autopct='%1.1f%%',shadow=True, startangle=90,ax = ax[0,1])
ax[0,1].set_title('Survived')
ax[0,1].set_ylabel('')
dataset[['Sex','Survived']].groupby(['Sex']).mean().plot.bar(ax = ax[1,0])
sns.countplot('Sex',hue='Survived',data=dataset,ax = ax[1,1])
ax[1,1].set_title('Sex:Survived vs Dead')
# Out:
# <img src="data:image/png;base64,..." width="1000">
# Text(0.5,1,'Sex:Survived vs Dead')

# %% [markdown]
# From the graphs we can see that women survived more, out of the total women , majority women survived

# %%
f,ax=plt.subplots(2,2,figsize=(10,10))
sns.countplot(dataset['Embarked'],ax=ax[0,0])
ax[0,0].set_title('No. Of Passengers Boarded')
sns.countplot(dataset['Embarked'],hue=dataset['Sex'],ax = ax[0,1])
ax[0,1].set_title('Male-Female Split for Embarked')
sns.countplot(dataset['Embarked'],hue=dataset['Survived'],ax=ax[1,0])
ax[1,0].set_title('Embarked vs Survived')
sns.countplot(dataset['Embarked'],hue=dataset['Pclass'],ax=ax[1,1])
ax[1,1].set_title('Embarked vs Pclass')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
f,ax=plt.subplots(figsize=(5,5))
sns.barplot(dataset['SibSp'],dataset['Survived'],ax=ax)
ax.set_title('SibSp vs Survived')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="500">
# /home/kingston/.local/lib/python2.7/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# SibSp having 1 sibling had more chances of survival

# %% [markdown]
# ## Data Analysis

# %% [markdown]
# #### Size of data

# %%
dataset.shape
# Out:
# (891, 12)

# %% [markdown]
# #### Counting NaN values in Dataset

# %%
dataset.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# For cabin column
# Out of 891 total entries, 687 are NaNs, which constitutes to 78% of data, hence have to remove it as there is no point working over it

# %%
dataset = dataset.drop(columns = ['Cabin'])
dataset.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Embarked
# 0      0         A/5 21171   7.2500        S
# 1      0          PC 17599  71.2833        C
# 2      0  STON/O2. 3101282   7.9250        S
# 3      0            113803  53.1000        S
# 4      0            373450   8.0500        S

# %% [markdown]
#  We will check where we need to impute the data or drop (Age column). Based on the correlation of it with the final variable.To do that we need to find the correlation of not Nan dataset.

# %%
nn_dataset = dataset.dropna()

# %%
nn_dataset.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Embarked
# 0      0         A/5 21171   7.2500        S
# 1      0          PC 17599  71.2833        C
# 2      0  STON/O2. 3101282   7.9250        S
# 3      0            113803  53.1000        S
# 4      0            373450   8.0500        S

# %% [markdown]
# We need to convert the text to numerical format before finding correlations

# %%
processed_df = preprocess_df(nn_dataset)
# print(processed_df)
processed_df.head()
# Out:
#    PassengerId  Survived  Pclass  Name  Sex   Age  SibSp  Parch  Ticket  \
# 0            1         0       3   103    1  22.0      1      0     407
# 1            2         1       1   179    0  38.0      1      0     470
# 2            3         1       3   317    0  26.0      0      0     531
# 3            4         1       1   247    0  35.0      1      0      39
# 4            5         0       3    15    1  35.0      0      0     372
#
#       Fare  Embarked
# 0   7.2500         2
# 1  71.2833         0
# 2   7.9250         2
# 3  53.1000         2
# 4   8.0500         2

# %%
corr = processed_df.corr()

# %%
plt.figure(figsize=(9,9))
sns.heatmap(corr, xticklabels=corr.columns,yticklabels=corr.columns,annot=True,cmap='RdYlGn')
# Out:
# <img src="data:image/png;base64,..." width="900">

# %% [markdown]
# Here we can see that, there is no correation at all of columns Age, PassengerID, Name, SibSp & Parch. So we can drop those

# %%
processed_df = processed_df.drop(columns = ['Age', 'PassengerId', 'Name', 'SibSp', 'Parch'])

# %%
processed_df.head()
# Out:
#    Survived  Pclass  Sex  Ticket     Fare  Embarked
# 0         0       3    1     407   7.2500         2
# 1         1       1    0     470  71.2833         0
# 2         1       3    0     531   7.9250         2
# 3         1       1    0      39  53.1000         2
# 4         0       3    1     372   8.0500         2
